# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("laptops.csv")
df
# Out:
#       id  brand             model  ram hd_type  hd_size  screen_size   price  \
# 0      1   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1      2  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2      3  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3      4  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4      5  Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..   ...    ...               ...  ...     ...      ...          ...     ...
# 158  166   Asus            A555LF    8     hdd     1024         15.6   39961
# 159  167   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 160  168   Asus            X554LD    2     hdd      500         15.6   29199
# 161  169   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 162  170   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# 0             intel              i5          2.5              intel
# 1             intel              i5          1.8              intel
# 2             intel              i5          1.8              intel
# 3             intel              i5          2.3              intel
# 4             intel              i5          2.3              intel
# ..              ...             ...          ...                ...
# 158           intel      i3 4th gen          1.7             nvidia
# 159           intel      i3 4th gen          1.9              intel
# 160           intel      i3 4th gen          1.9              intel
# 161           intel      i3 4th gen          1.7              intel
# 162           intel      i3 5th gen          2.0              intel
#
#      graphic_card_size       os  weight comments
# 0                  NaN    linux    2.50      NaN
# 1                  2.0      mac    1.35      NaN
# 2                  2.0      mac    1.35      NaN
# 3                  2.0      mac    3.02      NaN
# 4                  2.0      mac    3.02      NaN
# ..                 ...      ...     ...      ...
# 158                2.0  windows    2.30      NaN
# 159                NaN    linux    2.30      NaN
# 160                1.0    linux    2.30      NaN
# 161                NaN    linux    2.50      NaN
# 162                NaN  windows    2.30      NaN
#
# [163 rows x 16 columns]

# %%
df.drop(["id","model","comments"],axis="columns",inplace=True)
df
# Out:
#      brand  ram hd_type  hd_size  screen_size   price processor_brand  \
# 0     Dell    4     hdd     1024         15.6   40000           intel
# 1    Apple    8     ssd      128         13.3   55499           intel
# 2    Apple    8     ssd      256         13.3   71500           intel
# 3    Apple    8     ssd      128         13.3   96890           intel
# 4    Apple    8     ssd      256         13.3  112666           intel
# ..     ...  ...     ...      ...          ...     ...             ...
# 158   Asus    8     hdd     1024         15.6   39961           intel
# 159   Asus    4     hdd      500         15.6   28489           intel
# 160   Asus    2     hdd      500         15.6   29199           intel
# 161   Asus    2     hdd      500         15.6   29990           intel
# 162   Asus    4     hdd     1024         15.6   30899           intel
#
#     processor_model  clock_speed graphic_card_brand  graphic_card_size  \
# 0                i5          2.5              intel                NaN
# 1                i5          1.8              intel                2.0
# 2                i5          1.8              intel                2.0
# 3                i5          2.3              intel                2.0
# 4                i5          2.3              intel                2.0
# ..              ...          ...                ...                ...
# 158      i3 4th gen          1.7             nvidia                2.0
# 159      i3 4th gen          1.9              intel                NaN
# 160      i3 4th gen          1.9              intel                1.0
# 161      i3 4th gen          1.7              intel                NaN
# 162      i3 5th gen          2.0              intel                NaN
#
#           os  weight
# 0      linux    2.50
# 1        mac    1.35
# 2        mac    1.35
# 3        mac    3.02
# 4        mac    3.02
# ..       ...     ...
# 158  windows    2.30
# 159    linux    2.30
# 160    linux    2.30
# 161    linux    2.50
# 162  windows    2.30
#
# [163 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# brand                  0
# ram                    0
# hd_type                0
# hd_size                0
# screen_size            0
# price                  0
# processor_brand        0
# processor_model        0
# clock_speed            1
# graphic_card_brand     4
# graphic_card_size     84
# os                     0
# weight                 7
# dtype: int64

# %%
df = df.fillna({"graphic_card_size":0,"weight":df.weight.mean(),"clock_speed":df.clock_speed.mean()})

# %%
df.isnull().sum()
# Out:
# brand                 0
# ram                   0
# hd_type               0
# hd_size               0
# screen_size           0
# price                 0
# processor_brand       0
# processor_model       0
# clock_speed           0
# graphic_card_brand    4
# graphic_card_size     0
# os                    0
# weight                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.brand.value_counts()
# Out:
# HP           39
# Acer         34
# Dell         26
# Lenovo       18
# HP           15
# Asus          8
# Alienware     6
# Microsoft     6
# Apple         6
# Asus          1
# Name: brand, dtype: int64

# %%
df.brand.replace({"Asus ":"Asus","HP ":"HP"},inplace=True)
df
# Out:
#      brand  ram hd_type  hd_size  screen_size   price processor_brand  \
# 0     Dell    4     hdd     1024         15.6   40000           intel
# 1    Apple    8     ssd      128         13.3   55499           intel
# 2    Apple    8     ssd      256         13.3   71500           intel
# 3    Apple    8     ssd      128         13.3   96890           intel
# 4    Apple    8     ssd      256         13.3  112666           intel
# ..     ...  ...     ...      ...          ...     ...             ...
# 158   Asus    8     hdd     1024         15.6   39961           intel
# 159   Asus    4     hdd      500         15.6   28489           intel
# 160   Asus    2     hdd      500         15.6   29199           intel
# 161   Asus    2     hdd      500         15.6   29990           intel
# 162   Asus    4     hdd     1024         15.6   30899           intel
#
#     processor_model  clock_speed graphic_card_brand  graphic_card_size  \
# 0                i5          2.5              intel                0.0
# 1                i5          1.8              intel                2.0
# 2                i5          1.8              intel                2.0
# 3                i5          2.3              intel                2.0
# 4                i5          2.3              intel                2.0
# ..              ...          ...                ...                ...
# 158      i3 4th gen          1.7             nvidia                2.0
# 159      i3 4th gen          1.9              intel                0.0
# 160      i3 4th gen          1.9              intel                1.0
# 161      i3 4th gen          1.7              intel                0.0
# 162      i3 5th gen          2.0              intel                0.0
#
#           os  weight
# 0      linux    2.50
# 1        mac    1.35
# 2        mac    1.35
# 3        mac    3.02
# 4        mac    3.02
# ..       ...     ...
# 158  windows    2.30
# 159    linux    2.30
# 160    linux    2.30
# 161    linux    2.50
# 162  windows    2.30
#
# [159 rows x 13 columns]

# %%
df.brand.value_counts()
# Out:
# HP           54
# Acer         34
# Dell         26
# Lenovo       18
# Asus          9
# Alienware     6
# Microsoft     6
# Apple         6
# Name: brand, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
brand_encoder = LabelEncoder()
df.brand = brand_encoder.fit_transform(df.brand)
brand_encoder.classes_
# Out:
# array(['Acer', 'Alienware', 'Apple', 'Asus', 'Dell', 'HP', 'Lenovo',
#        'Microsoft'], dtype=object)

# %%
df.ram.dtype
# Out:
# dtype('int64')

# %%
hdtype_encoder = LabelEncoder()
df.hd_type = hdtype_encoder.fit_transform(df.hd_type)
df
# Out:
#      brand  ram  hd_type  hd_size  screen_size   price processor_brand  \
# 0        4    4        0     1024         15.6   40000           intel
# 1        2    8        1      128         13.3   55499           intel
# 2        2    8        1      256         13.3   71500           intel
# 3        2    8        1      128         13.3   96890           intel
# 4        2    8        1      256         13.3  112666           intel
# ..     ...  ...      ...      ...          ...     ...             ...
# 158      3    8        0     1024         15.6   39961           intel
# 159      3    4        0      500         15.6   28489           intel
# 160      3    2        0      500         15.6   29199           intel
# 161      3    2        0      500         15.6   29990           intel
# 162      3    4        0     1024         15.6   30899           intel
#
#     processor_model  clock_speed graphic_card_brand  graphic_card_size  \
# 0                i5          2.5              intel                0.0
# 1                i5          1.8              intel                2.0
# 2                i5          1.8              intel                2.0
# 3                i5          2.3              intel                2.0
# 4                i5          2.3              intel                2.0
# ..              ...          ...                ...                ...
# 158      i3 4th gen          1.7             nvidia                2.0
# 159      i3 4th gen          1.9              intel                0.0
# 160      i3 4th gen          1.9              intel                1.0
# 161      i3 4th gen          1.7              intel                0.0
# 162      i3 5th gen          2.0              intel                0.0
#
#           os  weight
# 0      linux    2.50
# 1        mac    1.35
# 2        mac    1.35
# 3        mac    3.02
# 4        mac    3.02
# ..       ...     ...
# 158  windows    2.30
# 159    linux    2.30
# 160    linux    2.30
# 161    linux    2.50
# 162  windows    2.30
#
# [159 rows x 13 columns]

# %%
hdtype_encoder.classes_
# Out:
# array(['hdd', 'ssd'], dtype=object)

# %%
df.hd_size.dtype
# Out:
# dtype('int64')

# %%
df.screen_size.dtype
# Out:
# dtype('float64')

# %%
df.price.dtype
# Out:
# dtype('int64')

# %%
df1 = df[df.processor_brand=="intel"]

# %%
df1.drop("processor_brand",axis="columns",inplace=True)
df1
# Out:
#      brand  ram  hd_type  hd_size  screen_size   price processor_model  \
# 0        4    4        0     1024         15.6   40000              i5
# 1        2    8        1      128         13.3   55499              i5
# 2        2    8        1      256         13.3   71500              i5
# 3        2    8        1      128         13.3   96890              i5
# 4        2    8        1      256         13.3  112666              i5
# ..     ...  ...      ...      ...          ...     ...             ...
# 158      3    8        0     1024         15.6   39961      i3 4th gen
# 159      3    4        0      500         15.6   28489      i3 4th gen
# 160      3    2        0      500         15.6   29199      i3 4th gen
# 161      3    2        0      500         15.6   29990      i3 4th gen
# 162      3    4        0     1024         15.6   30899      i3 5th gen
#
#      clock_speed graphic_card_brand  graphic_card_size       os  weight
# 0            2.5              intel                0.0    linux    2.50
# 1            1.8              intel                2.0      mac    1.35
# 2            1.8              intel                2.0      mac    1.35
# 3            2.3              intel                2.0      mac    3.02
# 4            2.3              intel                2.0      mac    3.02
# ..           ...                ...                ...      ...     ...
# 158          1.7             nvidia                2.0  windows    2.30
# 159          1.9              intel                0.0    linux    2.30
# 160          1.9              intel                1.0    linux    2.30
# 161          1.7              intel                0.0    linux    2.50
# 162          2.0              intel                0.0  windows    2.30
#
# [150 rows x 12 columns]

# %%
df1.processor_model.value_counts()
# Out:
# i5                   70
# i7                   30
# i3                   28
# i3 4th gen            4
# Atom Z8300            2
# Pentium N3710         2
# i3 5th gen            2
# i3                    2
# Pentium Quad Core     1
# Pentium 3805U         1
# Celeron               1
# Celeron N3060         1
# i3 6th gen            1
# Pentium N3700         1
# pentium               1
# Pentium               1
# Pentium N3825U        1
# I3                    1
# Name: processor_model, dtype: int64

# %%
def pro(x):
    x=x.lower()
    y=x.split(" ")[0]
    if y.startswith("i"):
        return y
    else:
        return "other"

# %%
df1.processor_model = df1.processor_model.apply(pro)

# %%
df1
# Out:
#      brand  ram  hd_type  hd_size  screen_size   price processor_model  \
# 0        4    4        0     1024         15.6   40000              i5
# 1        2    8        1      128         13.3   55499              i5
# 2        2    8        1      256         13.3   71500              i5
# 3        2    8        1      128         13.3   96890              i5
# 4        2    8        1      256         13.3  112666              i5
# ..     ...  ...      ...      ...          ...     ...             ...
# 158      3    8        0     1024         15.6   39961              i3
# 159      3    4        0      500         15.6   28489              i3
# 160      3    2        0      500         15.6   29199              i3
# 161      3    2        0      500         15.6   29990              i3
# 162      3    4        0     1024         15.6   30899              i3
#
#      clock_speed graphic_card_brand  graphic_card_size       os  weight
# 0            2.5              intel                0.0    linux    2.50
# 1            1.8              intel                2.0      mac    1.35
# 2            1.8              intel                2.0      mac    1.35
# 3            2.3              intel                2.0      mac    3.02
# 4            2.3              intel                2.0      mac    3.02
# ..           ...                ...                ...      ...     ...
# 158          1.7             nvidia                2.0  windows    2.30
# 159          1.9              intel                0.0    linux    2.30
# 160          1.9              intel                1.0    linux    2.30
# 161          1.7              intel                0.0    linux    2.50
# 162          2.0              intel                0.0  windows    2.30
#
# [150 rows x 12 columns]

# %%
processor_model_encoder = LabelEncoder()
df1.processor_model = processor_model_encoder.fit_transform(df1.processor_model)
processor_model_encoder.classes_
# Out:
# array(['i3', 'i5', 'i7', 'other'], dtype=object)

# %%
df1.clock_speed.dtype
# Out:
# dtype('float64')

# %%
df1.graphic_card_brand.value_counts()
# Out:
# intel     75
# nvidia    48
# amd       27
# Name: graphic_card_brand, dtype: int64

# %%
graphic_brand_encoder = LabelEncoder()
df1.graphic_card_brand = graphic_brand_encoder.fit_transform(df1.graphic_card_brand)
graphic_brand_encoder.classes_
# Out:
# array(['amd', 'intel', 'nvidia'], dtype=object)

# %%
df1.graphic_card_size.dtype
# Out:
# dtype('float64')

# %%
df1.os.value_counts()
# Out:
# windows          112
# linux             31
# mac                6
# windows,linux      1
# Name: os, dtype: int64

# %%
df2=df1[df1.os!="windows,linux"]

# %%
os_encoder = LabelEncoder()
df2.os = os_encoder.fit_transform(df2.os)
os_encoder.classes_
# Out:
# array(['linux', 'mac', 'windows'], dtype=object)

# %%
df2.weight.dtype
# Out:
# dtype('float64')

# %%
# df2.drop("brand",axis="columns",inplace=True)

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# df2[["ram","hd_size","screen_size","clock_speed","graphic_card_size","weight"]] = scaler.fit_transform(df2[["ram","hd_size","screen_size","clock_speed","graphic_card_size","weight"]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df2.drop("price",axis="columns"),df2.price,test_size=0.1)

# %%
from sklearn.linear_model import LinearRegression
l = LinearRegression()
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import joblib
joblib.dump(l,"model_trial")
l.score(x_test,y_test) , l.score(x_train,y_train)
# Out:
# (0.7292990659732037, 0.6374517150953596)

# %%
l.predict(x_test)
# Out:
# array([141800.57335637, 104298.45238594,  78812.42347821,  34972.93405932,
#         48196.24818584,  13630.20961697,  31102.75205477,  21943.5563074 ,
#         30540.8932091 ,  60144.045601  ,  53227.89321858,  57765.08436341,
#         90282.38429116,  54316.29973837,  64617.32336181])

# %%
y_test
# Out:
# 39     169280
# 33     101882
# 151     58990
# 130     40890
# 85      43990
# 64      33990
# 127     40490
# 62      41990
# 111     24890
# 48      87576
# 24      50680
# 99      42990
# 59      91890
# 152     61000
# 144     13872
# Name: price, dtype: int64

# %%
x_test
# Out:
#      brand  ram  hd_type  hd_size  screen_size  processor_model  clock_speed  \
# 39       5   16        1      512         13.3                2         2.70
# 33       5    8        1      256         13.3                2         2.50
# 151      6    8        0     1024         15.6                1         3.10
# 130      5    4        0     1024         15.6                1         2.30
# 85       6    4        0     1024         15.6                1         3.10
# 64       5    4        0     1024         15.6                0         2.00
# 127      5    4        0     1024         11.6                0         2.40
# 62       6    4        0     1024         15.6                1         2.30
# 111      0    4        0     1024         15.6                0         2.30
# 48       0    8        0     1024         15.6                1         2.20
# 24       0    8        0     1024         15.6                2         2.50
# 99       5    8        0     1024         15.6                1         2.50
# 59       4    8        0     1024         15.6                2         3.80
# 152      6    8        0     2048         15.6                1         3.10
# 144      0    2        1       32         10.1                3         1.44
#
#      graphic_card_brand  graphic_card_size  os    weight
# 39                    1                0.0   2  2.239872
# 33                    1                1.0   2  2.239872
# 151                   2                4.0   2  2.200000
# 130                   0                2.0   2  2.190000
# 85                    1                2.0   2  2.200000
# 64                    0                0.0   0  2.100000
# 127                   0                0.0   2  1.390000
# 62                    0                2.0   0  2.300000
# 111                   1                0.0   0  3.360000
# 48                    1                0.0   2  2.400000
# 24                    1                2.0   0  2.400000
# 99                    0                2.0   2  2.100000
# 59                    2                4.0   2  2.800000
# 152                   2                4.0   2  2.200000
# 144                   1                0.0   2  1.200000
